# %% [markdown]
# **CAMPANA DE GAUSS**

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Función para calcular la distribución de probabilidad
def pdf(x):
    mean = np.mean(x)
    std = np.std(x)
    y_out = 1 / (std * np.sqrt(2 * np.pi)) * np.exp(-(x - mean) ** 2 / (2 * std ** 2))
    return y_out

# Generar un arreglo de x
x = np.arange(-4, 4, 0.1)

# Generar arreglo de y, correspondiente a los valores de x, valor centrado en 0, desviación estándar = 1
y = norm.pdf(x, 0, 1)

# Declarar variables para sombrear el área bajo la curva
x_fill = np.arange(-2, 2, 0.1)
y_fill = norm.pdf(x_fill, 0, 1)

# Gráfica
plt.style.use('ggplot')  # Cambia 'ggplot' por 'seaborn-whitegrid' si prefieres ese estilo
plt.figure(figsize=(6, 6))
plt.plot(x, y, color='black', linestyle='dashed')
plt.scatter(x, y, marker='o', s=25, color='red')
plt.fill_between(x_fill, y_fill, 0, alpha=0.2, color='yellow')
plt.show()
